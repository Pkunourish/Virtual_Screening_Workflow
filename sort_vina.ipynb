# %%
import pandas as pd

# %%
input_file = './sort_1443_vinascore.csv'
output_file = 'sort_1443_vinascore_top10.csv'

# %%
res = pd.read_csv('./sort_1443_vinascore.csv', sep = ' ')
top10_mol = res[res['score']<-7.6].copy()
top10_mol.to_csv("sort_1443_vinascore_top10.csv", index=False)
